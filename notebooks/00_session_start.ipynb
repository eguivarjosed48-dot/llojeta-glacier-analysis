# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pathlib import Path
import sys

REPO_PATH = Path("/content/drive/MyDrive/geo_projects/llojeta-glacier-analysis/repo")
SRC_PATH = REPO_PATH / "src"

print("REPO_PATH =", REPO_PATH)
print("SRC_PATH  =", SRC_PATH)

assert REPO_PATH.exists(), f"No existe el repo en: {REPO_PATH}"
assert SRC_PATH.exists(), f"No existe src/ en: {SRC_PATH}"
# Out:
# REPO_PATH = /content/drive/MyDrive/geo_projects/llojeta-glacier-analysis/repo
# SRC_PATH  = /content/drive/MyDrive/geo_projects/llojeta-glacier-analysis/repo/src

# %%
# %cd /content/drive/MyDrive/geo_projects/llojeta-glacier-analysis/repo

# !pwd
# !git status
# Out:
# /content/drive/MyDrive/geo_projects/llojeta-glacier-analysis/repo
# /content/drive/MyDrive/geo_projects/llojeta-glacier-analysis/repo
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	notebooks/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !pip install -q -r /content/drive/MyDrive/geo_projects/llojeta-glacier-analysis/repo/requirements.txt
print("Dependencias listas.")
# Out:
# Dependencias listas.

# %%
if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

print("src añadido a sys.path")
print(sys.path[:3])
# Out:
# src añadido a sys.path
# ['/content/drive/MyDrive/geo_projects/llojeta-glacier-analysis/repo/src', '/content', '/env/python']

# %%
from pathlib import Path

print("Repo existe:", REPO_PATH.exists())
print("requirements existe:", (REPO_PATH / "requirements.txt").exists())
print("config existe:", (REPO_PATH / "config").exists())
print("projectio existe:", (REPO_PATH / "src" / "projectio").exists())
# Out:
# Repo existe: True
# requirements existe: True
# config existe: True
# projectio existe: True
