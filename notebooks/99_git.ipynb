# %% [markdown]
# carga Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Ubicacion

# %%
# %cd /content/drive/MyDrive/geo_projects/llojeta-glacier-analysis/repo
# !pwd
# Out:
# /content/drive/MyDrive/geo_projects/llojeta-glacier-analysis/repo
# /content/drive/MyDrive/geo_projects/llojeta-glacier-analysis/repo

# %% [markdown]
# Ver estado

# %%
# !git status
# Out:
# On branch main
# nothing to commit, working tree clean

# %% [markdown]
# commit rápido

# %%
mensaje = "update"

# !git add .
# !git commit -m "{mensaje}"
# !git status
# Out:
# [main 30ac16a] update
#  3 files changed, 3 insertions(+), 3 deletions(-)
#  rewrite notebooks/00_session_start.ipynb (94%)
#  rewrite notebooks/01_project_config.ipynb (95%)
#  rewrite notebooks/99_git.ipynb (89%)
# On branch main
# nothing to commit, working tree clean

# %% [markdown]
# commit con mensaje manual

# %%
mensaje = input("Mensaje de commit: ")

# !git add .
# !git commit -m "{mensaje}"

# %% [markdown]
# push

# %%
mensaje = input("Mensaje de commit: ")

# !git add .
# !git commit -m "{mensaje}"
