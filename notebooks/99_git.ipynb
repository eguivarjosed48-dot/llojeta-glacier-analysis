# %% [markdown]
# carga Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Ubicacion

# %%
# %cd /content/drive/MyDrive/geo_projects/llojeta-glacier-analysis/repo
# !pwd

# %% [markdown]
# Ver estado

# %%
# !git status
# Out:
# On branch main
# nothing to commit, working tree clean

# %% [markdown]
# commit rápido

# %%
mensaje = "update"

# !git add .
# !git commit -m "{mensaje}"
# !git status
# Out:
# [main 0acbc35] update
#  4 files changed, 159 insertions(+), 2 deletions(-)
#  rewrite notebooks/01_project_config.ipynb (83%)
#  create mode 100644 notebooks/02_raster_intake
#  rewrite notebooks/99_git.ipynb (83%)
#  create mode 100644 src/projectio/raster_inventory.py
# On branch main
# nothing to commit, working tree clean

# %% [markdown]
# commit con mensaje manual

# %%
mensaje = input("Mensaje de commit: ")

# !git add .
# !git commit -m "{mensaje}"

# %% [markdown]
# push

# %%
mensaje = input("Mensaje de commit: ")

# !git add .
# !git commit -m "{mensaje}"
